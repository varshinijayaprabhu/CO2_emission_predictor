# %% [markdown]
# # PROJECT NAME : Predicting CO2 Emissions from Fuel Consumption Data using Machine Learning

# %% [markdown]
# ### Project Type

# %% [markdown]
# #### Regression analysis with machine learning techniques is the focus of this study. By utilizing regression analysis, one or more independent factors, such as engine size, cylinder count, and fuel consumption metrics, may be utilized to predict a continuous dependent variable, in this instance CO2 emissions.

# %% [markdown]
# #### * UNDERSTANDING GIVEN DATASET : the dataset provides model specific fuel consumption ratings and estimated carbon di oxide emission for new light duty vehicals for retail sale in canada for year 2019

# %% [markdown]
# #### Understanding the dataset :
# #### * The dataset used in this project is the "Fuel Consumption 2019" dataset, which contains information about various vehicle attributes and their corresponding CO2 emissions. This dataset includes features such as engine size, number of cylinders, and fuel consumption in different driving conditions.
# #### * the dataset provides model specific fuel consumption ratings and estimated carbon di oxide emission for new light duty vehicals for retail sale in canada for year 2019

# %% [markdown]
# #### Objective :
# #### * To explore and preprocess the dataset.
# #### * To build multiple regression models for predicting CO2 emissions.
# #### * To evaluate the performance of each model using the R2-score.
# #### * To identify the best-performing model for accurate predictions

# %% [markdown]
# # working on the model

# %% [markdown]
# ## we are importing the necessary libraries here

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## reading the dataset

# %%
df = pd.read_excel("Fuel consumption 2019.xlsx")
df.head()
# Out:
#    Model-Year   Make              Model Vehicle-Class  Engine-Size  Cylinders  \
# 0        2019  Acura                ILX       Compact          2.4        NaN
# 1        2019  Acura         MDX SH-AWD    SUV: Small          3.5        6.0
# 2        2019  Acura  MDX SH-AWD A-SPEC    SUV: Small          NaN        6.0
# 3        2019  Acura     MDX Hybrid AWD    SUV: Small          3.0        6.0
# 4        2019  Acura                NSX    Two-seater          3.5        6.0
#
#   Transmission Fuel-Type  Fuel-Consumption-City  Fuel-Consumption-Hwy  \
# 0          AM8         Z                    9.9                   7.0
# 1          AS9         Z                   12.2                   9.0
# 2          AS9         Z                   12.2                   9.5
# 3          AM7         Z                    9.1                   9.0
# 4          AM9         Z                   11.1                  10.8
#
#    Fuel-Consumption-Comb  CO2-Emissions
# 0                    8.6            199
# 1                   10.8            252
# 2                   11.0            258
# 3                    9.0            210
# 4                   11.0            261

# %% [markdown]
# ## checking the number of rows and columns in the dataset

# %%
df.shape
# Out:
# (1046, 12)

# %% [markdown]
# ## understanding  the structure and details of our dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046 entries, 0 to 1045
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Model-Year             1046 non-null   int64
#  1   Make                   1046 non-null   object
#  2   Model                  1046 non-null   object
#  3   Vehicle-Class          1046 non-null   object
#  4   Engine-Size            1042 non-null   float64
#  5   Cylinders              1037 non-null   float64
#  6   Transmission           1046 non-null   object
#  7   Fuel-Type              1046 non-null   object
#  8   Fuel-Consumption-City  1046 non-null   float64
#  9   Fuel-Consumption-Hwy   1046 non-null   float64
#  10  Fuel-Consumption-Comb  1046 non-null   float64
#  11  CO2-Emissions          1046 non-null   int64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 98.2+ KB

# %% [markdown]
# ## understand the basic statistics and distribution of the dataset

# %%
df.describe()
# Out:
#        Model-Year  Engine-Size    Cylinders  Fuel-Consumption-City  \
# count      1046.0  1042.000000  1037.000000            1046.000000
# mean       2019.0     3.104702     5.584378              12.378011
# std           0.0     1.312420     1.787415               3.294286
# min        2019.0     1.000000     3.000000               4.200000
# 25%        2019.0     2.000000     4.000000              10.200000
# 50%        2019.0     3.000000     6.000000              12.050000
# 75%        2019.0     3.600000     6.000000              14.300000
# max        2019.0     8.000000    16.000000              26.800000
#
#        Fuel-Consumption-Hwy  Fuel-Consumption-Comb  CO2-Emissions
# count           1046.000000            1046.000000    1046.000000
# mean               9.038050              10.872562     251.312620
# std                2.049742               2.697321      57.017573
# min                4.000000               4.100000      96.000000
# 25%                7.600000               9.100000     212.250000
# 50%                8.800000              10.600000     248.000000
# 75%               10.200000              12.575000     289.000000
# max               17.200000              22.200000     522.000000

# %% [markdown]
# ### Checking for Missing Values

# %%
df.isna()
# Out:
#       Model-Year   Make  Model  Vehicle-Class  Engine-Size  Cylinders  \
# 0          False  False  False          False        False       True
# 1          False  False  False          False        False      False
# 2          False  False  False          False         True      False
# 3          False  False  False          False        False      False
# 4          False  False  False          False        False      False
# ...          ...    ...    ...            ...          ...        ...
# 1041       False  False  False          False        False      False
# 1042       False  False  False          False        False      False
# 1043       False  False  False          False        False      False
# 1044       False  False  False          False        False      False
# 1045       False  False  False          False        False      False
#
#       Transmission  Fuel-Type  Fuel-Consumption-City  Fuel-Consumption-Hwy  \
# 0            False      False                  False                 False
# 1            False      False                  False                 False
# 2            False      False                  False                 False
# 3            False      False                  False                 False
# 4            False      False                  False                 False
# ...            ...        ...                    ...                   ...
# 1041         False      False                  False                 False
# 1042         False      False                  False                 False
# 1043         False      False                  False                 False
# 1044         False      False                  False                 False
# 1045         False      False                  False                 False
#
#       Fuel-Consumption-Comb  CO2-Emissions
# 0                     False          False
# 1                     False          False
# 2                     False          False
# 3                     False          False
# 4                     False          False
# ...                     ...            ...
# 1041                  False          False
# 1042                  False          False
# 1043                  False          False
# 1044                  False          False
# 1045                  False          False
#
# [1046 rows x 12 columns]

# %% [markdown]
# ### creating a copy of the dataset

# %%
df1=df.copy(deep=True)

# %% [markdown]
# ### Checking for Missing Values in the Copied Dataset

# %%
df1.isna().sum()
# Out:
# Model-Year               0
# Make                     0
# Model                    0
# Vehicle-Class            0
# Engine-Size              4
# Cylinders                9
# Transmission             0
# Fuel-Type                0
# Fuel-Consumption-City    0
# Fuel-Consumption-Hwy     0
# Fuel-Consumption-Comb    0
# CO2-Emissions            0
# dtype: int64

# %% [markdown]
# ### fill missing values in the 'Engine-Size' column with its mean

# %%
mn=df1["Engine-Size"].mean()
df1["Engine-Size"]=df1["Engine-Size"].fillna(mn)

# %%
df1.head(25)
# Out:
#     Model-Year          Make                     Model Vehicle-Class  \
# 0         2019         Acura                       ILX       Compact
# 1         2019         Acura                MDX SH-AWD    SUV: Small
# 2         2019         Acura         MDX SH-AWD A-SPEC    SUV: Small
# 3         2019         Acura            MDX Hybrid AWD    SUV: Small
# 4         2019         Acura                       NSX    Two-seater
# 5         2019         Acura                   RDX AWD    SUV: Small
# 6         2019         Acura            RDX AWD A-SPEC    SUV: Small
# 7         2019         Acura                RLX Hybrid      Mid-size
# 8         2019         Acura                       TLX       Compact
# 9         2019         Acura                TLX A-SPEC       Compact
# 10        2019         Acura                TLX SH-AWD       Compact
# 11        2019         Acura         TLX SH-AWD A-SPEC       Compact
# 12        2019    Alfa Romeo                  4C Coupe    Two-seater
# 13        2019    Alfa Romeo                 4C Spider    Two-seater
# 14        2019    Alfa Romeo                    Giulia      Mid-size
# 15        2019    Alfa Romeo                Giulia AWD      Mid-size
# 16        2019    Alfa Romeo       Giulia Quadrifoglio      Mid-size
# 17        2019    Alfa Romeo                   Stelvio    SUV: Small
# 18        2019    Alfa Romeo               Stelvio AWD    SUV: Small
# 19        2019    Alfa Romeo  Stelvio AWD Quadrifoglio    SUV: Small
# 20        2019  Aston Martin                   DB11 V8   Minicompact
# 21        2019  Aston Martin                  DB11 AMR   Minicompact
# 22        2019  Aston Martin          DBS Superleggera   Minicompact
# 23        2019  Aston Martin                Rapide AMR    Subcompact
# 24        2019  Aston Martin           Vanquish Zagato   Minicompact
#
#     Engine-Size  Cylinders Transmission Fuel-Type  Fuel-Consumption-City  \
# 0      2.400000        NaN          AM8         Z                    9.9
# 1      3.500000        6.0          AS9         Z                   12.2
# 2      3.104702        6.0          AS9         Z                   12.2
# 3      3.000000        6.0          AM7         Z                    9.1
# 4      3.500000        6.0          AM9         Z                   11.1
# 5      2.000000        4.0         AS10         Z                   11.0
# 6      2.000000        4.0         AS10         Z                   11.3
# 7      3.500000        6.0          AM7         Z                    8.4
# 8      2.400000        4.0          AM8         Z                   10.0
# 9      2.400000        4.0          AM8         Z                   10.2
# 10     3.500000        6.0          AS9         Z                   11.4
# 11     3.500000        6.0          AS9         Z                   12.0
# 12     1.800000        4.0          AM6         Z                    9.7
# 13     1.800000        4.0          AM6         Z                    9.7
# 14     2.000000        4.0           A8         Z                   10.0
# 15     2.000000        4.0           A8         Z                   10.5
# 16     2.900000        6.0           A8         Z                   13.8
# 17     2.000000        4.0           A8         Z                   10.3
# 18     2.000000        4.0           A8         Z                   10.8
# 19     2.900000        6.0           A8         Z                   14.1
# 20     4.000000        8.0           A8         Z                   13.0
# 21     5.200000        NaN           A8         Z                   15.5
# 22     5.200000       12.0           A8         Z                   16.4
# 23     6.000000       12.0           A8         Z                   16.7
# 24     6.000000       12.0           A8         Z                   17.5
#
#     Fuel-Consumption-Hwy  Fuel-Consumption-Comb  CO2-Emissions
# 0                    7.0                    8.6            199
# 1                    9.0                   10.8            252
# 2                    9.5                   11.0            258
# 3                    9.0                    9.0            210
# 4                   10.8                   11.0            261
# 5                    8.6                    9.9            232
# 6                    9.1                   10.3            242
# 7                    8.2                    8.4            196
# 8                    7.1                    8.7            205
# 9                    7.4                    8.9            209
# 10                   7.7                    9.8            228
# 11                   8.2                   10.3            240
# 12                   6.9                    8.4            197
# 13                   6.9                    8.4            197
# 14                   7.2                    8.7            205
# 15                   7.7                    9.2            217
# 16                   9.6                   11.9            280
# 17                   8.1                    9.3            218
# 18                   8.3                    9.6            226
# 19                  10.4                   12.4            292
# 20                   9.8                   11.5            271
# 21                  10.6                   13.3            312
# 22                  10.7                   13.8            324
# 23                  10.9                   14.1            332
# 24                  11.4                   14.7            346

# %% [markdown]
# ### checking if the missing values in 'engine-size' is filled

# %%
df1.isna().sum()
# Out:
# Model-Year               0
# Make                     0
# Model                    0
# Vehicle-Class            0
# Engine-Size              0
# Cylinders                9
# Transmission             0
# Fuel-Type                0
# Fuel-Consumption-City    0
# Fuel-Consumption-Hwy     0
# Fuel-Consumption-Comb    0
# CO2-Emissions            0
# dtype: int64

# %% [markdown]
# ### fill missing values in the 'Cylinders' column with its median

# %%
md=df1["Cylinders"].median()
df1["Cylinders"]=df1["Cylinders"].fillna(md)

# %%
df1.head(25)
# Out:
#     Model-Year          Make                     Model Vehicle-Class  \
# 0         2019         Acura                       ILX       Compact
# 1         2019         Acura                MDX SH-AWD    SUV: Small
# 2         2019         Acura         MDX SH-AWD A-SPEC    SUV: Small
# 3         2019         Acura            MDX Hybrid AWD    SUV: Small
# 4         2019         Acura                       NSX    Two-seater
# 5         2019         Acura                   RDX AWD    SUV: Small
# 6         2019         Acura            RDX AWD A-SPEC    SUV: Small
# 7         2019         Acura                RLX Hybrid      Mid-size
# 8         2019         Acura                       TLX       Compact
# 9         2019         Acura                TLX A-SPEC       Compact
# 10        2019         Acura                TLX SH-AWD       Compact
# 11        2019         Acura         TLX SH-AWD A-SPEC       Compact
# 12        2019    Alfa Romeo                  4C Coupe    Two-seater
# 13        2019    Alfa Romeo                 4C Spider    Two-seater
# 14        2019    Alfa Romeo                    Giulia      Mid-size
# 15        2019    Alfa Romeo                Giulia AWD      Mid-size
# 16        2019    Alfa Romeo       Giulia Quadrifoglio      Mid-size
# 17        2019    Alfa Romeo                   Stelvio    SUV: Small
# 18        2019    Alfa Romeo               Stelvio AWD    SUV: Small
# 19        2019    Alfa Romeo  Stelvio AWD Quadrifoglio    SUV: Small
# 20        2019  Aston Martin                   DB11 V8   Minicompact
# 21        2019  Aston Martin                  DB11 AMR   Minicompact
# 22        2019  Aston Martin          DBS Superleggera   Minicompact
# 23        2019  Aston Martin                Rapide AMR    Subcompact
# 24        2019  Aston Martin           Vanquish Zagato   Minicompact
#
#     Engine-Size  Cylinders Transmission Fuel-Type  Fuel-Consumption-City  \
# 0      2.400000        6.0          AM8         Z                    9.9
# 1      3.500000        6.0          AS9         Z                   12.2
# 2      3.104702        6.0          AS9         Z                   12.2
# 3      3.000000        6.0          AM7         Z                    9.1
# 4      3.500000        6.0          AM9         Z                   11.1
# 5      2.000000        4.0         AS10         Z                   11.0
# 6      2.000000        4.0         AS10         Z                   11.3
# 7      3.500000        6.0          AM7         Z                    8.4
# 8      2.400000        4.0          AM8         Z                   10.0
# 9      2.400000        4.0          AM8         Z                   10.2
# 10     3.500000        6.0          AS9         Z                   11.4
# 11     3.500000        6.0          AS9         Z                   12.0
# 12     1.800000        4.0          AM6         Z                    9.7
# 13     1.800000        4.0          AM6         Z                    9.7
# 14     2.000000        4.0           A8         Z                   10.0
# 15     2.000000        4.0           A8         Z                   10.5
# 16     2.900000        6.0           A8         Z                   13.8
# 17     2.000000        4.0           A8         Z                   10.3
# 18     2.000000        4.0           A8         Z                   10.8
# 19     2.900000        6.0           A8         Z                   14.1
# 20     4.000000        8.0           A8         Z                   13.0
# 21     5.200000        6.0           A8         Z                   15.5
# 22     5.200000       12.0           A8         Z                   16.4
# 23     6.000000       12.0           A8         Z                   16.7
# 24     6.000000       12.0           A8         Z                   17.5
#
#     Fuel-Consumption-Hwy  Fuel-Consumption-Comb  CO2-Emissions
# 0                    7.0                    8.6            199
# 1                    9.0                   10.8            252
# 2                    9.5                   11.0            258
# 3                    9.0                    9.0            210
# 4                   10.8                   11.0            261
# 5                    8.6                    9.9            232
# 6                    9.1                   10.3            242
# 7                    8.2                    8.4            196
# 8                    7.1                    8.7            205
# 9                    7.4                    8.9            209
# 10                   7.7                    9.8            228
# 11                   8.2                   10.3            240
# 12                   6.9                    8.4            197
# 13                   6.9                    8.4            197
# 14                   7.2                    8.7            205
# 15                   7.7                    9.2            217
# 16                   9.6                   11.9            280
# 17                   8.1                    9.3            218
# 18                   8.3                    9.6            226
# 19                  10.4                   12.4            292
# 20                   9.8                   11.5            271
# 21                  10.6                   13.3            312
# 22                  10.7                   13.8            324
# 23                  10.9                   14.1            332
# 24                  11.4                   14.7            346

# %% [markdown]
# ### checking if the missing values in "cylinders" is filed

# %%
df1.isna().sum()
# Out:
# Model-Year               0
# Make                     0
# Model                    0
# Vehicle-Class            0
# Engine-Size              0
# Cylinders                0
# Transmission             0
# Fuel-Type                0
# Fuel-Consumption-City    0
# Fuel-Consumption-Hwy     0
# Fuel-Consumption-Comb    0
# CO2-Emissions            0
# dtype: int64

# %% [markdown]
# ### Splitting Categorical and Numerical Features

# %%
categorical_features = df1.columns[(df1.dtypes == 'object') == True].to_list()
numerical_df1 = df1.drop(categorical_features, axis=1)
categorical_df1 = df1[categorical_features]

# %%
numerical_df1.head(25)
# Out:
#     Model-Year  Engine-Size  Cylinders  Fuel-Consumption-City  \
# 0         2019     2.400000        6.0                    9.9
# 1         2019     3.500000        6.0                   12.2
# 2         2019     3.104702        6.0                   12.2
# 3         2019     3.000000        6.0                    9.1
# 4         2019     3.500000        6.0                   11.1
# 5         2019     2.000000        4.0                   11.0
# 6         2019     2.000000        4.0                   11.3
# 7         2019     3.500000        6.0                    8.4
# 8         2019     2.400000        4.0                   10.0
# 9         2019     2.400000        4.0                   10.2
# 10        2019     3.500000        6.0                   11.4
# 11        2019     3.500000        6.0                   12.0
# 12        2019     1.800000        4.0                    9.7
# 13        2019     1.800000        4.0                    9.7
# 14        2019     2.000000        4.0                   10.0
# 15        2019     2.000000        4.0                   10.5
# 16        2019     2.900000        6.0                   13.8
# 17        2019     2.000000        4.0                   10.3
# 18        2019     2.000000        4.0                   10.8
# 19        2019     2.900000        6.0                   14.1
# 20        2019     4.000000        8.0                   13.0
# 21        2019     5.200000        6.0                   15.5
# 22        2019     5.200000       12.0                   16.4
# 23        2019     6.000000       12.0                   16.7
# 24        2019     6.000000       12.0                   17.5
#
#     Fuel-Consumption-Hwy  Fuel-Consumption-Comb  CO2-Emissions
# 0                    7.0                    8.6            199
# 1                    9.0                   10.8            252
# 2                    9.5                   11.0            258
# 3                    9.0                    9.0            210
# 4                   10.8                   11.0            261
# 5                    8.6                    9.9            232
# 6                    9.1                   10.3            242
# 7                    8.2                    8.4            196
# 8                    7.1                    8.7            205
# 9                    7.4                    8.9            209
# 10                   7.7                    9.8            228
# 11                   8.2                   10.3            240
# 12                   6.9                    8.4            197
# 13                   6.9                    8.4            197
# 14                   7.2                    8.7            205
# 15                   7.7                    9.2            217
# 16                   9.6                   11.9            280
# 17                   8.1                    9.3            218
# 18                   8.3                    9.6            226
# 19                  10.4                   12.4            292
# 20                   9.8                   11.5            271
# 21                  10.6                   13.3            312
# 22                  10.7                   13.8            324
# 23                  10.9                   14.1            332
# 24                  11.4                   14.7            346

# %%
categorical_df1.head(25)
# Out:
#             Make                     Model Vehicle-Class Transmission  \
# 0          Acura                       ILX       Compact          AM8
# 1          Acura                MDX SH-AWD    SUV: Small          AS9
# 2          Acura         MDX SH-AWD A-SPEC    SUV: Small          AS9
# 3          Acura            MDX Hybrid AWD    SUV: Small          AM7
# 4          Acura                       NSX    Two-seater          AM9
# 5          Acura                   RDX AWD    SUV: Small         AS10
# 6          Acura            RDX AWD A-SPEC    SUV: Small         AS10
# 7          Acura                RLX Hybrid      Mid-size          AM7
# 8          Acura                       TLX       Compact          AM8
# 9          Acura                TLX A-SPEC       Compact          AM8
# 10         Acura                TLX SH-AWD       Compact          AS9
# 11         Acura         TLX SH-AWD A-SPEC       Compact          AS9
# 12    Alfa Romeo                  4C Coupe    Two-seater          AM6
# 13    Alfa Romeo                 4C Spider    Two-seater          AM6
# 14    Alfa Romeo                    Giulia      Mid-size           A8
# 15    Alfa Romeo                Giulia AWD      Mid-size           A8
# 16    Alfa Romeo       Giulia Quadrifoglio      Mid-size           A8
# 17    Alfa Romeo                   Stelvio    SUV: Small           A8
# 18    Alfa Romeo               Stelvio AWD    SUV: Small           A8
# 19    Alfa Romeo  Stelvio AWD Quadrifoglio    SUV: Small           A8
# 20  Aston Martin                   DB11 V8   Minicompact           A8
# 21  Aston Martin                  DB11 AMR   Minicompact           A8
# 22  Aston Martin          DBS Superleggera   Minicompact           A8
# 23  Aston Martin                Rapide AMR    Subcompact           A8
# 24  Aston Martin           Vanquish Zagato   Minicompact           A8
#
#    Fuel-Type
# 0          Z
# 1          Z
# 2          Z
# 3          Z
# 4          Z
# 5          Z
# 6          Z
# 7          Z
# 8          Z
# 9          Z
# 10         Z
# 11         Z
# 12         Z
# 13         Z
# 14         Z
# 15         Z
# 16         Z
# 17         Z
# 18         Z
# 19         Z
# 20         Z
# 21         Z
# 22         Z
# 23         Z
# 24         Z

# %% [markdown]
# ### Correlation Matrix for Numerical Features

# %%
numerical_df1.corr()
# Out:
#                        Model-Year  Engine-Size  Cylinders  \
# Model-Year                    NaN          NaN        NaN
# Engine-Size                   NaN     1.000000   0.920886
# Cylinders                     NaN     0.920886   1.000000
# Fuel-Consumption-City         NaN     0.829609   0.810614
# Fuel-Consumption-Hwy          NaN     0.759530   0.731791
# Fuel-Consumption-Comb         NaN     0.816626   0.794058
# CO2-Emissions                 NaN     0.833432   0.819747
#
#                        Fuel-Consumption-City  Fuel-Consumption-Hwy  \
# Model-Year                               NaN                   NaN
# Engine-Size                         0.829609              0.759530
# Cylinders                           0.810614              0.731791
# Fuel-Consumption-City               1.000000              0.942301
# Fuel-Consumption-Hwy                0.942301              1.000000
# Fuel-Consumption-Comb               0.993338              0.974168
# CO2-Emissions                       0.934762              0.903503
#
#                        Fuel-Consumption-Comb  CO2-Emissions
# Model-Year                               NaN            NaN
# Engine-Size                         0.816626       0.833432
# Cylinders                           0.794058       0.819747
# Fuel-Consumption-City               0.993338       0.934762
# Fuel-Consumption-Hwy                0.974168       0.903503
# Fuel-Consumption-Comb               1.000000       0.936493
# CO2-Emissions                       0.936493       1.000000

# %% [markdown]
# ### Encoding Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder
if isinstance(categorical_df1, pd.Series):
    categorical_df1 = categorical_df1.to_frame()
le = LabelEncoder()
encoded_categorical_df1 = categorical_df1.apply(lambda col: le.fit_transform(col.astype(str)) if col.dtype == 'object' else col)
combined_df = pd.concat([numerical_df1, encoded_categorical_df1], axis=1)
correlation_matrix = combined_df.corr()
print(correlation_matrix)
# Out:
#                        Model-Year  Engine-Size  Cylinders  \
# Model-Year                    NaN          NaN        NaN
# Engine-Size                   NaN     1.000000   0.920886
# Cylinders                     NaN     0.920886   1.000000
# Fuel-Consumption-City         NaN     0.829609   0.810614
# Fuel-Consumption-Hwy          NaN     0.759530   0.731791
# Fuel-Consumption-Comb         NaN     0.816626   0.794058
# CO2-Emissions                 NaN     0.833432   0.819747
# Make                          NaN    -0.137240  -0.117407
# Model                         NaN     0.036869   0.003193
# Vehicle-Class                 NaN     0.102896   0.074717
# Transmission                  NaN    -0.343967  -0.306686
# Fuel-Type                     NaN     0.080665   0.159331
#
#                        Fuel-Consumption-City  Fuel-Consumption-Hwy  \
# Model-Year                               NaN                   NaN
# Engine-Size                         0.829609              0.759530
# Cylinders                           0.810614              0.731791
# Fuel-Consumption-City               1.000000              0.942301
# Fuel-Consumption-Hwy                0.942301              1.000000
# Fuel-Consumption-Comb               0.993338              0.974168
# CO2-Emissions                       0.934762              0.903503
# Make                               -0.157211             -0.120087
# Model                               0.034276              0.088896
# Vehicle-Class                       0.180460              0.223543
# Transmission                       -0.329345             -0.347282
# Fuel-Type                           0.064563              0.004658
#
#                        Fuel-Consumption-Comb  CO2-Emissions      Make  \
# Model-Year                               NaN            NaN       NaN
# Engine-Size                         0.816626       0.833432 -0.137240
# Cylinders                           0.794058       0.819747 -0.117407
# Fuel-Consumption-City               0.993338       0.934762 -0.157211
# Fuel-Consumption-Hwy                0.974168       0.903503 -0.120087
# Fuel-Consumption-Comb               1.000000       0.936493 -0.147471
# CO2-Emissions                       0.936493       1.000000 -0.125131
# Make                               -0.147471      -0.125131  1.000000
# Model                               0.053333       0.037658 -0.130487
# Vehicle-Class                       0.197683       0.220622 -0.065839
# Transmission                       -0.340433      -0.329451  0.192915
# Fuel-Type                           0.044485       0.142216  0.077640
#
#                           Model  Vehicle-Class  Transmission  Fuel-Type
# Model-Year                  NaN            NaN           NaN        NaN
# Engine-Size            0.036869       0.102896     -0.343967   0.080665
# Cylinders              0.003193       0.074717     -0.306686   0.159331
# Fuel-Consumption-City  0.034276       0.180460     -0.329345   0.064563
# Fuel-Consumption-Hwy   0.088896       0.223543     -0.347282   0.004658
# Fuel-Consumption-Comb  0.053333       0.197683     -0.340433   0.044485
# CO2-Emissions          0.037658       0.220622     -0.329451   0.142216
# Make                  -0.130487      -0.065839      0.192915   0.077640
# Model                  1.000000       0.036147     -0.000343  -0.121249
# Vehicle-Class          0.036147       1.000000     -0.069293   0.090903
# Transmission          -0.000343      -0.069293      1.000000   0.154629
# Fuel-Type             -0.121249       0.090903      0.154629   1.000000

# %% [markdown]
# ### Encoding Target Variable (y)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
if isinstance(categorical_df1, pd.DataFrame):
    categorical_df1 = categorical_df1.iloc[:, 0]
y = le.fit_transform(categorical_df1)
print(y)
# Out:
# [ 0  0  0 ... 38 38 38]

# %% [markdown]
# ### Encoding Multiple Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

cols = ["Make", "Model", "Vehicle-Class", "Transmission", "Fuel-Type"]

for f in cols:
    df1[f] = df1[f].astype(str)  
    df1[f] = le.fit_transform(df1[f])

# %% [markdown]
# ### Correlation Matrix for Encoded DataFrame

# %%
df1.corr()
# Out:
#                        Model-Year      Make     Model  Vehicle-Class  \
# Model-Year                    NaN       NaN       NaN            NaN
# Make                          NaN  1.000000 -0.048927       0.011292
# Model                         NaN -0.048927  1.000000       0.036147
# Vehicle-Class                 NaN  0.011292  0.036147       1.000000
# Engine-Size                   NaN  0.010945  0.036869       0.102896
# Cylinders                     NaN  0.021093  0.003193       0.074717
# Transmission                  NaN  0.109352 -0.000343      -0.069293
# Fuel-Type                     NaN  0.186635 -0.121249       0.090903
# Fuel-Consumption-City         NaN -0.027353  0.034276       0.180460
# Fuel-Consumption-Hwy          NaN -0.053635  0.088896       0.223543
# Fuel-Consumption-Comb         NaN -0.037244  0.053333       0.197683
# CO2-Emissions                 NaN  0.002636  0.037658       0.220622
#
#                        Engine-Size  Cylinders  Transmission  Fuel-Type  \
# Model-Year                     NaN        NaN           NaN        NaN
# Make                      0.010945   0.021093      0.109352   0.186635
# Model                     0.036869   0.003193     -0.000343  -0.121249
# Vehicle-Class             0.102896   0.074717     -0.069293   0.090903
# Engine-Size               1.000000   0.920886     -0.343967   0.080665
# Cylinders                 0.920886   1.000000     -0.306686   0.159331
# Transmission             -0.343967  -0.306686      1.000000   0.154629
# Fuel-Type                 0.080665   0.159331      0.154629   1.000000
# Fuel-Consumption-City     0.829609   0.810614     -0.329345   0.064563
# Fuel-Consumption-Hwy      0.759530   0.731791     -0.347282   0.004658
# Fuel-Consumption-Comb     0.816626   0.794058     -0.340433   0.044485
# CO2-Emissions             0.833432   0.819747     -0.329451   0.142216
#
#                        Fuel-Consumption-City  Fuel-Consumption-Hwy  \
# Model-Year                               NaN                   NaN
# Make                               -0.027353             -0.053635
# Model                               0.034276              0.088896
# Vehicle-Class                       0.180460              0.223543
# Engine-Size                         0.829609              0.759530
# Cylinders                           0.810614              0.731791
# Transmission                       -0.329345             -0.347282
# Fuel-Type                           0.064563              0.004658
# Fuel-Consumption-City               1.000000              0.942301
# Fuel-Consumption-Hwy                0.942301              1.000000
# Fuel-Consumption-Comb               0.993338              0.974168
# CO2-Emissions                       0.934762              0.903503
#
#                        Fuel-Consumption-Comb  CO2-Emissions
# Model-Year                               NaN            NaN
# Make                               -0.037244       0.002636
# Model                               0.053333       0.037658
# Vehicle-Class                       0.197683       0.220622
# Engine-Size                         0.816626       0.833432
# Cylinders                           0.794058       0.819747
# Transmission                       -0.340433      -0.329451
# Fuel-Type                           0.044485       0.142216
# Fuel-Consumption-City               0.993338       0.934762
# Fuel-Consumption-Hwy                0.974168       0.903503
# Fuel-Consumption-Comb               1.000000       0.936493
# CO2-Emissions                       0.936493       1.000000

# %% [markdown]
# ### Feature Selection

# %%
x = df1[["Fuel-Consumption-Comb","Fuel-Consumption-City","Fuel-Consumption-Hwy","Engine-Size"]]
y = df1["CO2-Emissions"]
print(x,y)
# Out:
#       Fuel-Consumption-Comb  Fuel-Consumption-City  Fuel-Consumption-Hwy  \
# 0                       8.6                    9.9                   7.0
# 1                      10.8                   12.2                   9.0
# 2                      11.0                   12.2                   9.5
# 3                       9.0                    9.1                   9.0
# 4                      11.0                   11.1                  10.8
# ...                     ...                    ...                   ...
# 1041                    9.0                   10.3                   7.5
# 1042                   10.0                   11.3                   8.5
# 1043                   10.4                   11.8                   8.6
# 1044                   10.0                   11.3                   8.5
# 1045                   10.7                   12.1                   8.9
#
#       Engine-Size
# 0        2.400000
# 1        3.500000
# 2        3.104702
# 3        3.000000
# 4        3.500000
# ...           ...
# 1041     2.000000
# 1042     2.000000
# 1043     2.000000
# 1044     2.000000
# 1045     2.000000
#
# [1046 rows x 4 columns] 0       199
# 1       252
# 2       258
# 3       210
# 4       261
#        ...
# 1041    211
# 1042    233
# 1043    242
# 1044    233
# 1045    250
# Name: CO2-Emissions, Length: 1046, dtype: int64

# %% [markdown]
# ### Data Splitting for Model Training and Testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
print("Shape of the X Train :",x_train.shape)
print("Shape of the y Train :",y_train.shape)
print("Shape of the X test :",x_test.shape)
print("Shape of the y test :",y_test.shape)
# Out:
# Shape of the X Train : (836, 4)
# Shape of the y Train : (836,)
# Shape of the X test : (210, 4)
# Shape of the y test : (210,)

# %% [markdown]
# ### ML model implementation

# %% [markdown]
# ### linear regression
# #### Linear regression is a statistical method used to model the relationship between one or more independent variables and a dependent variable by fitting a linear equation to observed data, aiming to predict the dependent variable based on the independent variables.

# %%
from sklearn.linear_model import LinearRegression
slr= LinearRegression()
slr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
slr.coef_
slr.intercept_
# Out:
# np.float64(43.426524712048746)

# %%
ypred=slr.predict(x_test)
print(ypred)
# Out:
# [136.70922094 243.47748672 329.58316985 222.39607473 211.18988031
#  274.89918782 305.25116504 245.1450504  193.06764683 255.46915863
#  206.9341719  181.82681381 225.1163579  277.16155857 244.67058656
#  205.43391467 317.87445905 180.69426352 266.72624016 259.40175525
#  185.71623581 257.84236901 247.18661298 181.82295756 174.02786505
#  222.66331672 252.82810922 280.98212149 205.68573168 211.39331354
#  317.38179675 222.67102922 312.27175178 232.51154056 207.55613156
#  279.84578259 277.63987867 386.17339962 263.64210629 306.13325123
#  288.07542356 281.31762554 193.98579217 235.86594917 233.91186225
#  222.65560423 302.35444238 231.10350638 269.20354525 359.42622747
#  246.02268331 240.86864021 253.43628024 317.02262582 178.96229405
#  230.10612728 258.00528982 285.59403573 268.40922884 311.99050533
#  214.58888407 335.24206502 229.9142628  234.19838549 226.00615658
#  241.6541177  217.91244269 282.35219022 207.3725766  257.81561055
#  247.43071749 248.48789026 269.18617032 240.15007186 274.57139627
#  202.61399007 242.42802645 189.05907567 242.83950504 244.20376757
#  252.45268978 214.05054382 182.64835045 358.29314778 281.67959393
#  254.1472472  207.35329536 278.06232897 249.33006106 207.6321061
#  347.22407449 190.92947555 387.71818438 242.06945254 212.2992931
#  338.00492578 179.34542599 375.2410769  281.76433977 247.84084317
#  291.14656814 203.83183959 307.86847993 188.99852612 302.30823503
#  164.24730623 353.78371607 227.68143276 261.2925628  251.89839514
#  195.93987909 272.69328389 245.61951425 242.83950504 177.9533462
#  405.8365616  218.10977561 262.3298573  227.90022336 242.81501464
#  318.62192745 179.88043938 215.6614142  210.97880221 312.27175178
#  257.84622526 245.23199666 214.58117157 244.20376757 334.08910706
#  222.87000917 234.35554374 225.73891458 321.78121235 175.72763163
#  344.70217424 253.35791346 212.91360789 258.00528982 200.95799513
#  313.3418462  220.46126904 326.35842035 308.14729068 206.367485
#  313.32945395 227.41419076 273.15239038 281.24224803 268.62030693
#  312.27175178 242.26896189 265.53699658 365.69663998 234.19067299
#  329.51384901 200.68689688 200.42351113 231.11121888 200.68689688
#  210.77982226 227.33821622 239.39679727 219.33204561 349.28627123
#  329.58316985 260.93724811 227.43347201 192.33750973 179.88043938
#  268.40922884 255.34941244 302.51931313 245.1450504  232.51154056
#  195.66878084 251.63500939 321.02734073 372.67866423 171.25995398
#  239.46446228 198.08576287 241.13202596 221.27456379 255.17356998
#  248.48789026 270.32392976 307.00567498 212.6386534  242.05402755
#  240.13850311 184.04095963 215.20290475 220.99960929 228.91302745
#  214.33706707 200.29552305 210.69999147 219.33204561 269.43798732
#  208.29072194 269.94139485 210.06065687 396.09842152 247.75004067
#  212.91360789 291.28233635 225.56633134 202.07950607 210.78090506]

# %%
from sklearn.metrics import mean_absolute_error,r2_score
r2_score(y_test,ypred)
# Out:
# 0.8414755035850902

# %% [markdown]
# # the r2 score of linear regression model is 0.8414755035850898

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
rf = RandomForestRegressor()
rf.fit(x_train, y_train)

ypred_rf = rf.predict(x_test)

from sklearn.metrics import r2_score
print("RF R2:", r2_score(y_test, ypred_rf))
print("RF MAE:", mean_absolute_error(y_test, ypred_rf))
# Out:
# RF R2: 0.9683274640526676
# RF MAE: 3.6068376417233567

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, ypred_rf)
plt.xlabel("Actual CO2")
plt.ylabel("Predicted CO2")
plt.title("Actual vs Predicted (Random Forest)")
plt.show()

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor()
xgb.fit(x_train, y_train)

ypred_xgb = xgb.predict(x_test)

print("XGB R2:", r2_score(y_test, ypred_xgb))
print("XGB MAE:", mean_absolute_error(y_test, ypred_xgb))
# Out:
# XGB R2: 0.9666080474853516
# XGB MAE: 3.426039934158325

# %%
import pickle
import os

# This creates the pickle file exactly where the backend expects it
os.makedirs('backend', exist_ok=True)
with open("backend/co2_model.pkl", "wb") as f:
    pickle.dump(xgb, f)
print("XGBoost model saved! Check the 'backend' folder now.")
